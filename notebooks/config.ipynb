# %%
from pathlib import Path

# %%
PROJRCT_ROOT= Path.cwd().parent

# %%
Path.cwd()
# Out:
# WindowsPath('c:/Users/ganesh/Desktop/All Projects/Build Logistic Analysis Project/notebooks')

# %%
DATA_DIR= PROJRCT_ROOT / "data"

# %%
DATA_PATH= DATA_DIR / "APL_logistics.csv"

# %%
MODEL_DIR= PROJRCT_ROOT / "models"
MODEL_DIR
# Out:
# WindowsPath('c:/Users/ganesh/Desktop/All Projects/Build Logistic Analysis Project/models')

# %%
OUTPUT_DIR = PROJRCT_ROOT / "outputs"
OUTPUT_DIR
# Out:
# WindowsPath('c:/Users/ganesh/Desktop/All Projects/Build Logistic Analysis Project/outputs')

# %%
TARGET= "Late_delivery_risk"

# %%
LEAKAGE_COLUMNS= [
    "Late_delivery_risk",
    "Days for shipping (real)",
    "Delivery Status",
    "Order Status"
]
LEAKAGE_COLUMNS
# Out:
# ['Late_delivery_risk',
#  'Days for shipping (real)',
#  'Delivery Status',
#  'Order Status']

# %%
PII_COLUMNS= [
    "Customer Fname",
    "Customer Lname",
    "Customer Street",
    "Customer Id",
    "Oder Customer Id",
    "Customer Zipcode"
]

PII_COLUMNS
# Out:
# ['Customer Fname',
#  'Customer Lname',
#  'Customer Street',
#  'Customer Id',
#  'Oder Customer Id',
#  'Customer Zipcode']

# %%
HIGH_CARDINALITY_COLUMNS= [
    "Product Name",
    "Customer City",
    "Order City",
    "Order State"
]

HIGH_CARDINALITY_COLUMNS
# Out:
# ['Product Name', 'Customer City', 'Order City', 'Order State']

# %%
DROP_COLUMNS= LEAKAGE_COLUMNS + PII_COLUMNS
DROP_COLUMNS
# Out:
# ['Late_delivery_risk',
#  'Days for shipping (real)',
#  'Delivery Status',
#  'Order Status',
#  'Customer Fname',
#  'Customer Lname',
#  'Customer Street',
#  'Customer Id',
#  'Oder Customer Id',
#  'Customer Zipcode']

# %%
RANDOM_STATE= 42

# %%
TEST_SIZE= 0.20

# %%
NUMERIC_FEATURES= [
    "Days for shipment (scheduled)",
    "Benefit per order",
    "Sales per customer",
    "Category Id",
    "Department Id",
    "Latitude",
    "Longitude",
    "Order Item Discount",
    "Order Item Discount Rate",
    "Order Item Preduct Price",
    "Order Item Profit Ratio",
    "Order Item Quantity",
    "Sales",
    "Order Item Total",
    "Product Price"
]

NUMERIC_FEATURES
# Out:
# ['Days for shipment (scheduled)',
#  'Benefit per order',
#  'Sales per customer',
#  'Category Id',
#  'Department Id',
#  'Latitude',
#  'Longitude',
#  'Order Item Discount',
#  'Order Item Discount Rate',
#  'Order Item Preduct Price',
#  'Order Item Profit Ratio',
#  'Order Item Quantity',
#  'Sales',
#  'Order Item Total',
#  'Product Price']

# %%
CATEGORICAL_FEATURES= [
    "Type",
    "Category Name",
    "Customer Segment",
    "Customer State",
    "Department Name",
    "Market",
    "Order Country",
    "Order Region",
    "Product Name",
    "Shipping Mode"
]

CATEGORICAL_FEATURES
# Out:
# ['Type',
#  'Category Name',
#  'Customer Segment',
#  'Customer State',
#  'Department Name',
#  'Market',
#  'Order Country',
#  'Order Region',
#  'Product Name',
#  'Shipping Mode']
